# %%
import importlib
import pandas as pd
import matplotlib.pyplot as plt

# Save the updated code to create_graphs.py (optional - you'll need to do this manually)
# First update the file with the new code in fixed-create-graphs.py

# Then reload the module to use the updated code
import create_graphs
importlib.reload(create_graphs)

# Load the data
df = pd.read_csv('26Feb2025.csv')

# Use the new integrated function to show all visualizations
create_graphs.show_all_visualizations(df)
# Out:
# === Statistical Analysis Results ===
#
# Efficiency Metrics (per Mission):
# Total Kills: 307326
# Kills per mission: 112.86
# Stratagems per Mission: 20.48
# Objectives Per Mission: 4.97
# Deaths per Mission: 2.80
# Accuracy(%): 51.82
# Samples per Mission: 17.37
# XP per Mission: 1152.76
#
# Combat Style Distribution:
# Regular Kills: 247,755 (80.6%)
# Grenade Kills: 4,724 (1.5%)
# Melee Kills: 463 (0.2%)
# Eagle Kills: 54,384 (17.7%)
#
# Stratagem Efficiency (per Mission):
# Orbital Strikes: 3.05
# Defensive Tools: 4.90
# Eagle Support: 6.07
#
# Mission Performance Metrics:
# Success Rate: 96.0%
# Extraction Rate: 84.1%
# Objectives Completed per Mission: 4.97
# Samples Collected per Mission: 17.37
# XP Earned per Mission: 1152.76
